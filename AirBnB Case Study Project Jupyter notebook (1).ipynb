# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidance to answer the following questions.
#
# 1. Which hosts are the busiest and why?
# 2. How many neighborhood groups are available and which shows up the most?
# 3. Are private rooms the most popular in manhattan?
# 4. Which hosts are the busiest and based on their reviews?
# 5. Which neighorhood group has the highest average price?
# 6. Which neighborhood group has the highest total price?
# 7. Which top 5 hosts have the highest total price?
# 8. Who currently has no (zero) availability with a review count of 100 or more?
# 9. What host has the highest total of prices and where are they located?
# 10. When did Danielle from Queens last receive a review?
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this intire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to similate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
# How many neighborhood groups are available and which shows up the most?
ng = pd.read_csv('AB_NYC_2019.csv')['neighbourhood_group']
ng.describe(include='all')
# Using the Describe Method on only the neighborhood groups we can see that there are 5 unique groups, 
# and the one that shows up the most is Manhattan
# Out:
# count         48895
# unique            5
# top       Manhattan
# freq          21661
# Name: neighbourhood_group, dtype: object

# %%
# Are private rooms the most popular in manhattan?
Man = air_bnb[air_bnb['neighbourhood_group'] == 'Manhattan']
Man['room_type'].mode()

# No, The most poular room type in manhattan is Entire homes/apts
# Out:
# 0    Entire home/apt
# dtype: object

# %%
# Which hosts are the busiest and based on their reviews?
treviews = air_bnb.groupby(['host_id']).number_of_reviews.sum()
treviews.sort_values(ascending=False)

#Host 37312959 is the busiest based on their reviews
# Out:
# host_id
# 37312959     2273
# 344035       2205
# 26432133     2017
# 35524316     1971
# 40176101     1818
#              ...
# 140338526       0
# 24508767        0
# 140323391       0
# 140312311       0
# 274321313       0
# Name: number_of_reviews, Length: 37457, dtype: int64

# %%
#Which neighorhood group has the highest average price?
hood = air_bnb.groupby(['neighbourhood_group']).price.median().sort_values(ascending=False)
hood
#Manhattan has the highest average price
# Out:
# neighbourhood_group
# Manhattan        150
# Brooklyn          90
# Queens            75
# Staten Island     75
# Bronx             65
# Name: price, dtype: int64

# %%
# Which neighbor hood group has the highest total price?
hood = air_bnb.groupby(['neighbourhood_group']).price.sum().sort_values(ascending=False)
hood
#Manhattan has the highest total price
# Out:
# neighbourhood_group
# Manhattan        4264527
# Brooklyn         2500600
# Queens            563867
# Bronx              95459
# Staten Island      42825
# Name: price, dtype: int64

# %%
#Which top 5 hosts have the highest total price?
maxhost = air_bnb.groupby(['host_id']).price.sum()
maxhost.sort_values(ascending=False).head(5)

#Host 219517861 has the highest total price
# Out:
# host_id
# 219517861    82795
# 107434423    70331
# 156158778    37097
# 205031545    35294
# 30283594     33581
# Name: price, dtype: int64

# %%
# Who currently has no (zero) availability with a review count of 100 or more?
air_bnb.loc[(air_bnb['number_of_reviews']<= 100) & (air_bnb['availability_365']==0)]
# Out:
#              id                                               name    host_id  \
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 6          5121                                    BlissArtsSpace!       7356
# 14         6090                      West Village Nest - Superhost      11975
# 20         7801                   Sweet and Spacious Brooklyn Loft      21207
# 26         8700  Magnifique Suite au N de Manhattan - vue Cloitres      26394
# ...         ...                                                ...        ...
# 48550  36313048    Sunny room with private entrance in shared home   16883913
# 48731  36410519    Sunlight charming apt. in the heart of Brooklyn  121384174
# 48756  36419441                            Murray Hill Masterpiece  273824202
# 48760  36420725  Sunnyside, Queens 15 Mins to Midtown Clean & C...   19990280
# 48779  36424776  Queen size bedroom in two bed apt with great l...   13384464
#
# ...

# %%
# What host has the highest total of prices and where are they located?
maxhost = air_bnb.groupby('host_id').price.sum().sort_values(ascending=False).head()
maxhostmerge = air_bnb.merge(maxhost, on = 'host_id',how = 'inner')
highestpriceandlocation = maxhostmerge.sort_values('price_y',ascending=False).drop_duplicates(subset = 'host_id')
display(highestpriceandlocation[['host_id','host_name','neighbourhood_group','price_y']])
# Out:
#        host_id     host_name neighbourhood_group  price_y
# 740  219517861  Sonder (NYC)           Manhattan    82795
# 158  107434423    Blueground           Manhattan    70331
# 363  156158778         Sally           Manhattan    37097
# 370  205031545    Red Awning           Manhattan    35294
# 42    30283594          Kara           Manhattan    33581

# %%
# When did Danielle from Queens last receive a review?
danielle = air_bnb[(air_bnb['host_name']== 'Danielle')  & (air_bnb['neighbourhood_group'] == 'Queens') ]
danielle.sort_values('last_review', ascending=False)

#Last revuews was 2019-07-08
# Out:
#              id                                               name    host_id  \
# 22469  18173787  Cute Tiny Room Family Home by LGA NO CLEANING FEE   26432133
# 21517  17222454   Sun Room Family Home LGA Airport NO CLEANING FEE   26432133
# 20403  16276632  Cozy Room Family Home LGA Airport NO CLEANING FEE   26432133
# 22068  17754072                Bed in Family Home Near LGA Airport   26432133
# 7086    5115372  Comfy Room Family Home LGA Airport NO CLEANING...   26432133
# 33861  26814763  One bedroom with full bed / 1 stop from Manhattan  201647469
# 27021  21386105  Quiet & clean 1br haven with balcony near the ...  154256662
# 16349  13151075                    ASTORIA APARTMENT OUTDOOR SPACE   18051286
#
#       host_name neighbourhood_group     neighbourhood  latitude  longitude  \
# 22469  Danielle              Queens     East Elmhurst  40.76380  -73.87238
# 21517  Danielle              Queens     East Elmhurst  40.76367  -73.87088
# ...

# %% [markdown]
# ## Further Questions
#
# 1. Which host has the most listings?

# %%
maxhost = air_bnb.groupby(['host_id']).calculated_host_listings_count.sum()
maxhost.sort_values(ascending=False).head(5)
# Host 219517861 has the most listings
# Out:
# host_id
# 219517861    106929
# 107434423     53824
# 30283594      14641
# 137358866     10609
# 16098958       9216
# Name: calculated_host_listings_count, dtype: int64

# %% [markdown]
# 2. How many listings have completely open availability?

# %%
maxhost = air_bnb.groupby(['availability_365']).calculated_host_listings_count.sum()
maxhost.sort_values(ascending=False).head(5)
#
# Out:
# availability_365
# 0      25208
# 365    17040
# 364     7973
# 333     6847
# 332     6782
# Name: calculated_host_listings_count, dtype: int64

# %% [markdown]
# 3. What room_types have the highest review numbers?

# %%
maxhost = air_bnb.groupby(['room_type']).number_of_reviews.sum()
maxhost.sort_values(ascending=False).head(5)
# Out:
# room_type
# Entire home/apt    580403
# Private room       538346
# Shared room         19256
# Name: number_of_reviews, dtype: int64

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
